# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv(Path('Resources/income_all_yrs_station_cnt.csv'))
df
# Out:
#       income_yr_2019  income_yr_2020  income_yr_2021  stations_count
# 0            3852356         3984547         4136840               3
# 1             444992          477829          540998               1
# 2            6425619         6996323         7430981               4
# 3            5586182         6318254         6625114              32
# 4            4109003         4440817         4898980              10
# ...              ...             ...             ...             ...
# 1903         8532858         9191182         9861067              17
# 1904          377121          392641          423681               2
# 1905         1520192         1661083         1761765               4
# 1906          679397          697218          732110               3
# 1907         7510105         8039652         8677198               5
#
# [1908 rows x 4 columns]

# %%
plt.scatter(df.income_yr_2021, df.stations_count)
plt.xlabel("Income(in thousands of dollars)")
plt.ylabel('Fueling stations count')
plt.title('Total 2021 Houshold Income vs Fueling Stations Count per County')
plt.show()

# %%
X = df.income_yr_2021.values.reshape(-1, 1)

# %%
X[:5]
# Out:
# array([[4136840],
#        [ 540998],
#        [7430981],
#        [6625114],
#        [4898980]], dtype=int64)

# %%
X.shape
# Out:
# (1908, 1)

# %%
y = df.stations_count

# %%
y.shape
# Out:
# (1908,)

# %%
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)
print(y_pred.shape)
# Out:
# (1908,)

# %%
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')
plt.xlabel("Income(in thousands of dollars)")
plt.ylabel('Fueling stations count')
plt.title('Total 2021 Houshold Income vs Fueling Stations Count per County')
plt.show()

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [3.38852459e-06]
# -7.993316465932228

# %%
model.score(X,y)
# Out:
# 0.7492500177619099
