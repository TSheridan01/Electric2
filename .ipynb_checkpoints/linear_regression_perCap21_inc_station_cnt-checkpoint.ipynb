# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv(Path('Resources/income_perCapita21_station_cnt.csv'))
df
# Out:
#       per_capita_income_2021  stations_count
# 0                      59893               3
# 1                      50769               1
# 2                      46804               4
# 3                      43176              32
# 4                      49062              10
# ...                      ...             ...
# 1903                   43439              17
# 1904                   37839               2
# 1905                   45046               4
# 1906                   43341               3
# 1907                   52787               5
#
# [1908 rows x 2 columns]

# %%
plt.scatter(df.per_capita_income_2021, df.stations_count)
plt.xlabel("Per Capita Income")
plt.ylabel('Fueling stations count')
plt.title('Per Capita Houshold Income vs Fueling Stations Count per County')
plt.show()

# %%
X = df.per_capita_income_2021.values.reshape(-1, 1)

# %%
X.shape
# Out:
# (1908, 1)

# %%
y = df.stations_count

# %%
y.shape
# Out:
# (1908,)

# %%
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)
print(y_pred.shape)
# Out:
# (1908,)

# %%
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')
plt.xlabel("Per Capita Income")
plt.ylabel('Fueling stations count')
plt.title('Per Capita Houshold Income vs Fueling Stations Count per County')
plt.show()

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [0.00244944]
# -105.95505924734896

# %%
model.score(X,y)
# Out:
# 0.09485169250980674
