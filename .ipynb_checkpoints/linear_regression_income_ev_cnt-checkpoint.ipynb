# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv(Path('Resources/income_all_yrs_ev_count.csv'))
df.head()
# Out:
#   statecode_of_county        county  income_yr_2021  income_yr_2020  \
# 0                  CA  Contra Costa       115342618       103630133
# 1                  CA       Alameda       164437681       149239559
# 2                  CA        Alpine           89826           90114
# 3                  CA        Amador         2052718         1937437
# 4                  CA         Butte        11393205        10798585
#
#    income_yr_2019  ev_count
# 0        95239323    102886
# 1       135758980    192172
# 2           94986        38
# 3         1768935       768
# 4         9983194      3423

# %%
plt.scatter(df.income_yr_2021, df.ev_count)
plt.scatter(df.income_yr_2020, df.ev_count)
plt.scatter(df.income_yr_2019, df.ev_count)
plt.xlabel('Income in thousands of US dollars')
plt.ylabel('EV count')
plt.title('EV Adoption based on income per county in years 2019, 2020 and 2021')
plt.show()

# %%
X = df.income_yr_2021.values.reshape(-1, 1)

# %%
X[:5]
# Out:
# array([[115342618],
#        [164437681],
#        [    89826],
#        [  2052718],
#        [ 11393205]], dtype=int64)

# %%
y = df.ev_count

# %%
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)
print(y_pred.shape)
# Out:
# (521,)

# %%
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')
plt.xlabel('Income in thousands of US dollars')
plt.ylabel('EV count')
plt.title('EV Adoption based on 2021 income per county')
plt.show()

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [0.00076621]
# -2817.0603603962154

# %%
model.score(X,y)
# Out:
# 0.8430172561724961

# %%
X = df.income_yr_2020.values.reshape(-1, 1)
model.fit(X, y)
y_pred = model.predict(X)
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')
plt.xlabel('Income in thousands of US dollars')
plt.ylabel('EV count')
plt.title('EV Adoption based on 2020 income per county')
plt.show()

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [0.00081762]
# -2702.5787937282294

# %%
X = df.income_yr_2019.values.reshape(-1, 1)
model.fit(X, y)
y_pred = model.predict(X)
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')
plt.xlabel('Income in thousands of US dollars')
plt.ylabel('EV count')
plt.title('EV Adoption based on 2019 income per county')
plt.show()

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [0.00086386]
# -2585.0996283982477
