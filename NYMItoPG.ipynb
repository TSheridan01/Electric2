# %%
#Export NY and MI to Postgres

# %%
# Import our dependencies
import pandas as pd
import numpy as np
#import config as creds
import psycopg2
from sqlalchemy import create_engine

# %%
#create function to read data 
def read_data_from_file(name):
    data = []
    with open(name) as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')

        # skip the first row
        next(csv_reader)
        for row in csv_reader:
            data.append(row)
    return data

# %%
#read county NY csv files back in 

ny_counties_df = pd.read_csv('ny_ev_registrations_public_updated.csv', dtype=object,)

ny_counties_df
# Out:
#               County Registration Valid Date          Vehicle Name
# 0        Westchester                 3/27/19         Tesla Model 3
# 1        Westchester                12/24/18         Tesla Model 3
# 2        Westchester                 12/4/18         Tesla Model 3
# 3        Westchester                 12/1/18         Tesla Model 3
# 4        Westchester                11/29/18         Tesla Model 3
# ...              ...                     ...                   ...
# 1048570      Suffolk                 12/1/16  Toyota Prius Plug-in
# 1048571       Monroe                 3/26/18  Toyota Prius Plug-in
# 1048572       Ulster                 1/23/18  Toyota Prius Plug-in
# 1048573         Erie                 5/31/17  Toyota Prius Plug-in
# 1048574     Rockland                 4/13/17  Toyota Prius Plug-in
#
# [1048575 rows x 3 columns]

# %%
ny_counties_df.dtypes
# Out:
# County                     object
# Registration Valid Date    object
# Vehicle Name               object
# dtype: object

# %%
# altering the DataFrame
# new_ny_county_df = ny_counties_df

# %%
# keeping/adding relevant columns and renaming the columns
ny_counties_df["statecode_of_county"] = "NY"
ny_counties_df = ny_counties_df[['statecode_of_county','County',"Registration Valid Date","Vehicle Name"]]
ny_counties_df.columns = ['statecode_of_county','county', 'registration_date', 'vehicle_name']
ny_counties_df
# Out:
#         statecode_of_county       county registration_date  \
# 0                        NY  Westchester           3/27/19
# 1                        NY  Westchester          12/24/18
# 2                        NY  Westchester           12/4/18
# 3                        NY  Westchester           12/1/18
# 4                        NY  Westchester          11/29/18
# ...                     ...          ...               ...
# 1048570                  NY      Suffolk           12/1/16
# 1048571                  NY       Monroe           3/26/18
# 1048572                  NY       Ulster           1/23/18
# 1048573                  NY         Erie           5/31/17
# 1048574                  NY     Rockland           4/13/17
#
#                  vehicle_name
# 0               Tesla Model 3
# 1               Tesla Model 3
# 2               Tesla Model 3
# 3               Tesla Model 3
# 4               Tesla Model 3
# ...                       ...
# 1048570  Toyota Prius Plug-in
# ...

# %%
ny_counties_df["registration_date"] = pd.to_datetime(ny_counties_df["registration_date"])

# %%
ny_counties_df
# Out:
#         statecode_of_county       county registration_date  \
# 0                        NY  Westchester        2019-03-27
# 1                        NY  Westchester        2018-12-24
# 2                        NY  Westchester        2018-12-04
# 3                        NY  Westchester        2018-12-01
# 4                        NY  Westchester        2018-11-29
# ...                     ...          ...               ...
# 1048570                  NY      Suffolk        2016-12-01
# 1048571                  NY       Monroe        2018-03-26
# 1048572                  NY       Ulster        2018-01-23
# 1048573                  NY         Erie        2017-05-31
# 1048574                  NY     Rockland        2017-04-13
#
#                  vehicle_name
# 0               Tesla Model 3
# 1               Tesla Model 3
# 2               Tesla Model 3
# 3               Tesla Model 3
# 4               Tesla Model 3
# ...                       ...
# 1048570  Toyota Prius Plug-in
# ...

# %%
  #export to postgres 

db_string = f"postgresql://TomS:projectToms@dataviz.cp48egzju3un.us-east-1.rds.amazonaws.com:5432/Electric"
engine = create_engine(db_string)
conn = engine.connect()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3256, in Engine._wrap_pool_connect(self, fn, connection)
#    3255 try:
# -> 3256     return fn()
#    3257 except dialect.dbapi.Error as e:
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py:310, in Pool.connect(self)
#     303 """Return a DBAPI connection from the pool.
#     304
#     305 The connection is instrumented such that when its
#    (...)
#     308
#     309 """
# --> 310 return _ConnectionFairy._checkout(self)
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     867 if not fairy:
# --> 868     fairy = _ConnectionRecord.checkout(pool)
#     870     fairy._pool = pool
#
# ...

# %%
# new_nj_county_df.to_sql(name='ev_registration', con=conn, if_exists='append', index=False)
