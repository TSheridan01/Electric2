# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import OneHotEncoder
import pandas as pd
import tensorflow as tf

# %%
# Import our input dataset
fuel_df = pd.read_csv('Alternative_Fueling_Stations.csv')
fuel_df.head()

# %%
# X, Y are not needed. OBJECTID seems to be the index
# This data gets refreshed periodically
# We are probably concerned about columns longitude and latitude, access_code = "public",fuel_type_code = 'ELEC', 'HY' 
# latitude & longitude need to be translated to the county/city/state???????????????
# The following link gives the types: https://data-usdot.opendata.arcgis.com/datasets/usdot::alternative-fueling-stations/about 
fuel_df.fuel_type_code.value_counts()
# Out:
# ELEC    56764
# E85      4434
# LPG      2752
# CNG      1488
# BD       1197
# HY        142
# LNG       135
# Name: fuel_type_code, dtype: int64

# %%
fuel_df.access_code.value_counts()
# Out:
# public     61487
# private     5425
# Name: access_code, dtype: int64

# %%
# Battery Electric Vehicles (BEVs) and Plug-in Hybrid Electric Vehicles population
# All-electric vehicles—also referred to as battery electric vehicles (BEVs)—plug-in hybrid electric vehicles (PHEVs), and hybrid electric vehicles (HEVs) all use electricity to improve vehicle efficiency.

# %%
# Import our input dataset
income_df = pd.read_csv('CAINC1__ALL_AREAS_1969_2021.csv')
income_df.head()
# Out:
#     GeoFIPS        GeoName Region TableName  LineCode IndustryClassification  \
# 0   "00000"  United States           CAINC1         1                    ...
# 1   "00000"  United States           CAINC1         2                    ...
# 2   "00000"  United States           CAINC1         3                    ...
# 3   "01000"        Alabama      5    CAINC1         1                    ...
# 4   "01000"        Alabama      5    CAINC1         2                    ...
#
#                                Description                  Unit       1969  \
# 0  Personal income (thousands of dollars)   Thousands of dollars  791229000
# 1                  Population (persons) 1/     Number of persons  201298000
# 2  Per capita personal income (dollars) 2/               Dollars       3931
# 3  Personal income (thousands of dollars)   Thousands of dollars    9737715
# 4                  Population (persons) 1/     Number of persons    3440000
#
# ...

# %%
income_df.Description.value_counts()
# Out:
# Personal income (thousands of dollars)     3200
# Population (persons) 1/                    3200
# Per capita personal income (dollars) 2/    3200
# Name: Description, dtype: int64

# %%
income_df.GeoName.value_counts()
# Out:
# United States    3
# Hardin, OH       3
# Fairfield, OH    3
# Fayette, OH      3
# Franklin, OH     3
#                 ..
# Estill, KY       3
# Fayette, KY      3
# Fleming, KY      3
# Floyd, KY        3
# Far West         3
# Name: GeoName, Length: 3200, dtype: int64

# %%
income_df[income_df["GeoName"] == 'Franklin, OH']
# Out:
#        GeoFIPS       GeoName Region TableName  LineCode  \
# 6387   "39049"  Franklin, OH      3    CAINC1         1
# 6388   "39049"  Franklin, OH      3    CAINC1         2
# 6389   "39049"  Franklin, OH      3    CAINC1         3
#
#      IndustryClassification                              Description  \
# 6387                    ...  Personal income (thousands of dollars)
# 6388                    ...                  Population (persons) 1/
# 6389                    ...  Per capita personal income (dollars) 2/
#
#                       Unit     1969     1970  ...      2012      2013  \
# 6387  Thousands of dollars  3299601  3584118  ...  53336639  54041971
# 6388     Number of persons   815581   836409  ...   1199222   1219137
# 6389               Dollars     4046     4285  ...     44476     44328
#
#           2014      2015      2016      2017      2018      2019      2020  \
# 6387  56905420  60048305  61408548  63197230  65500158  67761223  73318378
# ...

# %%
# We are probably concerned about columns GeoName, 2020, 2021 where description="Personal income (thousands of dollars)"

# %%
# different dataset - county/GeoID/zip

# %%
# Import our CA dataset
ca_ev_df = pd.read_csv('ca_ev_registrations_public.csv')
ca_ev_df.head()
# Out:
# C:\Users\MEGHA\anaconda3\envs\mlenv\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        Vehicle ID County GEOID Registration Valid Date  DMV ID  \
# 0  CA-002-03597\r        06099              2011-01-01       2
# 1  CA-002-03598\r        06105              2011-01-01       2
# 2  CA-002-03599\r        06103              2011-01-01       2
# 3  CA-002-03600\r        06099              2011-01-01       2
# 4  CA-002-03601\r        06099              2011-01-01       2
#
#                                 DMV Snapshot  Registration Expiration Date  \
# 0  CA Registration Data from CA (12/31/2011)                           NaN
# 1  CA Registration Data from CA (12/31/2011)                           NaN
# 2  CA Registration Data from CA (12/31/2011)                           NaN
# ...

# %%
fl_ev_df = pd.read_csv('fl_ev_registrations_public.csv')
fl_ev_df.head()
# Out:
#    DMV ID                     DMV Snapshot (Date) County   Vehicle Name  \
# 0       1  Registration Data from FPL (6/30/2018)   Dade  Tesla Model X
# 1       1  Registration Data from FPL (6/30/2018)   Dade  Tesla Model X
# 2       1  Registration Data from FPL (6/30/2018)   Dade  Tesla Model X
# 3       1  Registration Data from FPL (6/30/2018)   Dade  Tesla Model X
# 4       1  Registration Data from FPL (6/30/2018)   Dade  Tesla Model X
#
#   Registration Valid Date  Registration Expiration Date Technology
# 0               6/30/2018                           NaN        BEV
# 1               6/30/2018                           NaN        BEV
# 2               6/30/2018                           NaN        BEV
# 3               6/30/2018                           NaN        BEV
# 4               6/30/2018                           NaN        BEV

# %%
mi_ev_df = pd.read_csv('mi_ev_registrations_public.csv')
mi_ev_df.head()
# Out:
#    DMV ID    DMV Snapshot (Date) Registration Valid Date  ZIP Code VIN Prefix  \
# 0       1  DMV Direct (3/3/2018)              11/14/2017     48380   1FADP5CU
# 1       1  DMV Direct (3/3/2018)              11/14/2017     48173   5YJSA1E4
# 2       1  DMV Direct (3/3/2018)              11/14/2017     48430   1G1RA6E4
# 3       1  DMV Direct (3/3/2018)              11/14/2017     48226   5YJSA1E2
# 4       1  DMV Direct (3/3/2018)              11/14/2017     48206   1G1RB6E4
#
#    Registration Expiration Date VIN Model Year       Make         Model  \
# 0                           NaN              D       Ford  C-Max Energi
# 1                           NaN              H      Tesla       Model S
# 2                           NaN              E  Chevrolet          Volt
# 3                           NaN              G      Tesla       Model S
# 4                           NaN              F  Chevrolet          Volt
#
#    Model Year
# 0        2013
# 1        2017
# 2        2014
# ...

# %%
ny_ev_df = pd.read_csv('ny_ev_registrations_public.csv')
ny_ev_df.head()
# Out:
# C:\Users\MEGHA\anaconda3\envs\mlenv\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    DMV ID               DMV Snapshot  ZIP Code State Registration Valid Date  \
# 0      39  NY DATA.NY.GOV (4/2/2020)     10583    NY               3/27/2019
# 1      39  NY DATA.NY.GOV (4/2/2020)     10583    NY              12/24/2018
# 2      39  NY DATA.NY.GOV (4/2/2020)     10583    NY               12/4/2018
# 3      39  NY DATA.NY.GOV (4/2/2020)     10583    NY               12/1/2018
# 4      39  NY DATA.NY.GOV (4/2/2020)     10583    NY              11/29/2018
#
#   Registration Expiration Date VIN Prefix VIN Model Year   Vehicle Name  \
# 0                   12/31/2020   5YJ3E1EB              J  Tesla Model 3
# 1                   12/23/2020   5YJ3E1EB              J  Tesla Model 3
# ...

# %%
tx_ev_df = pd.read_csv('TX_EV_Registrations.csv')
tx_ev_df.head()
# Out:
# C:\Users\MEGHA\anaconda3\envs\mlenv\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#   State ZIP Code Registration Date Vehicle Make Vehicle Model  \
# 0    TX    75251          6/1/2021        TESLA       Model 3
# 1    TX    76102          6/1/2021        TESLA       Model 3
# 2    TX    78224          6/1/2021        TESLA       Model 3
# 3    TX    75208          6/1/2021        TESLA       Model 3
# 4    TX    77573          6/1/2021        TESLA       Model 3
#
#    Vehicle Model Year Drivetrain Type Vehicle GVWR Class  \
# 0              2020.0             BEV                  1
# 1              2020.0             BEV                  1
# 2              2020.0             BEV                  1
# 3              2020.0             BEV                  1
# 4              2020.0             BEV                  1
#
# ...
