# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv(Path('Resources/income_all_yrs_ev_count.csv'))
df.head()
# Out:
#   statecode_of_county     county  income_yr_2021  income_yr_2020  \
# 0                  CA    Alameda       164437681       149239559
# 1                  CA     Alpine           89826           90114
# 2                  CA     Amador         2052718         1937437
# 3                  CA      Butte        11393205        10798585
# 4                  CA  Calaveras         2668137         2509072
#
#    income_yr_2019  ev_count
# 0       135758980    192172
# 1           94986        38
# 2         1768935       768
# 3         9983194      3423
# 4         2275336       999

# %%
plt.scatter(df.income_yr_2021, df.ev_count)
plt.scatter(df.income_yr_2020, df.ev_count)
plt.scatter(df.income_yr_2019, df.ev_count)
plt.xlabel('Income in thousands of US dollars')
plt.ylabel('EV count')
plt.title('EV Adoption based on income per county in years 2019, 2020 and 2021')
plt.show()

# %%
X = df.income_yr_2021.values.reshape(-1, 1)

# %%
X[:5]
# Out:
# array([[164437681],
#        [    89826],
#        [  2052718],
#        [ 11393205],
#        [  2668137]], dtype=int64)

# %%
y = df.ev_count

# %%
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)
print(y_pred.shape)
# Out:
# (521,)

# %%
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')
plt.xlabel('Income in thousands of US dollars')
plt.ylabel('EV count')
plt.title('EV Adoption based on 2021 income per county')
plt.show()

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [0.00076621]
# -2817.0603603962118

# %%
X = df.income_yr_2020.values.reshape(-1, 1)
model.fit(X, y)
y_pred = model.predict(X)
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')
plt.xlabel('Income in thousands of US dollars')
plt.ylabel('EV count')
plt.title('EV Adoption based on 2020 income per county')
plt.show()

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [0.00081762]
# -2702.578793728231

# %%
X = df.income_yr_2019.values.reshape(-1, 1)
model.fit(X, y)
y_pred = model.predict(X)
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')
plt.xlabel('Income in thousands of US dollars')
plt.ylabel('EV count')
plt.title('EV Adoption based on 2019 income per county')
plt.show()

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [0.00086386]
# -2585.0996283982513
